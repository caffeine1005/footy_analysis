# %%
import polars as pl
import polars.selectors as cs
import soccerdata as sd
import matplotlib.pyplot as plt
import sklearn as skl
import pandas as ps
import numpy as np
import pyarrow
import seaborn as sb
# Out:
# [12/20/25 11:23:17] INFO     No custom team name replacements found. You can configure these in       ]8;id=622519;file://C:\Users\User\anaconda3\envs\fbrefshit\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=306689;file://C:\Users\User\anaconda3\envs\fbrefshit\Lib\site-packages\soccerdata\_config.py#91\91]8;;\
#                              C:\Users\User\soccerdata\config\teamname_replacements.json.
#                     INFO     Custom league dict loaded from                                          ]8;id=546700;file://C:\Users\User\anaconda3\envs\fbrefshit\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=421422;file://C:\Users\User\anaconda3\envs\fbrefshit\Lib\site-packages\soccerdata\_config.py#195\195]8;;\
#                              C:\Users\User\soccerdata\config\league_dict.json.

# %%
fotmob = sd.FotMob(seasons="2025/2026")
print(fotmob.__doc__)
# Out:
# [12/20/25 11:23:31] INFO     Saving cached data to C:\Users\User\soccerdata\data\FotMob              ]8;id=80745;file://C:\Users\User\anaconda3\envs\fbrefshit\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=624272;file://C:\Users\User\anaconda3\envs\fbrefshit\Lib\site-packages\soccerdata\_common.py#263\263]8;;\
# [12/20/25 11:23:32] WARNING  C:\Users\User\anaconda3\envs\fbrefshit\Lib\site-packages\soccerdata\_c ]8;id=483169;file://C:\Users\User\anaconda3\envs\fbrefshit\Lib\warnings.py\warnings.py]8;;\:]8;id=668866;file://C:\Users\User\anaconda3\envs\fbrefshit\Lib\warnings.py#112\112]8;;\
#                              ommon.py:432: UserWarning: The leagues have different default season
#                              codes. Using multi-year season codes.
#                                return SeasonCode.from_leagues(self.leagues)
# Provides pd.DataFrames from data available at http://www.fotmob.com.
#
#     Data will be downloaded as necessary and cached locally in
# ...
